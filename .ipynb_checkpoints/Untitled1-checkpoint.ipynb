# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
from minisom import MiniSom
from pylab import plot, axis, show, pcolor, colorbar, bone

# %%
digits = load_digits()
data = digits.data
labels = digits.target

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
# Training the SOM
#from minisom import MiniSom
som = MiniSom(x = 16, y = 16, input_len = 64, sigma = 1, learning_rate = 0.7)
som.random_weights_init(data)
som.train_random(data = data, num_iteration = 100)
# Visualizing the results
from pylab import bone, pcolor, colorbar, plot, show
bone()
pcolor(som.distance_map().T)
colorbar()

# %%
data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
## labels -> k-meads 군집 라벨링
labels[labels =='0'] = 0 
labels[labels =='1'] = 1 
labels[labels =='2'] = 2 
labels[labels =='3'] = 3 
labels[labels =='4'] = 4 
labels[labels =='5'] = 5 
labels[labels =='6'] = 6 
labels[labels =='7'] = 7
labels[labels =='8'] = 8 
labels[labels =='9'] = 9 

markers = ['o', 'v', '1', '3', '8', 's', 'p', 'x', 'D', '*']
colors = ["r", "g", "b", "y", "c", (0,0.1,0.8), (1,0.5,0), (1,1,0.3), "m", (0.4,0.6,0)]

for cnt, xx in enumerate(data):
    w = som.winner(xx)
    plot(w[0] + 0.5,
         w[1] + 0.5,
         markers[labels[cnt]],
         markeredgecolor = colors[labels[cnt]],
         markerfacecolor = 'None',
         markersize = 10,
         markeredgewidth = 2)
#     axis([0, som.weights.shape[0], 0, som.weights.shape[1]])
show()
# Out:
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='0'] = 0
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:3: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='1'] = 1
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:4: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='2'] = 2
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:5: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='3'] = 3
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:6: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='4'] = 4
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='5'] = 5
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:8: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='6'] = 6
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:9: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='7'] = 7
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:10: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='8'] = 8
# C:\Users\sylee\AppData\Local\Temp\ipykernel_12420\2519125824.py:11: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   labels[labels =='9'] = 9
