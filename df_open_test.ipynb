# %%
# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
import matplotlib.pyplot as plt
# 그래프에서 한글 폰트 깨지는 문제에 대한 대처(전역 글꼴 설정)
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family=font_name)
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import seaborn as sns

# %%
path1 = 'C:/Users/sylee/Documents/GitHub/DataSafe/DataSafe/92dataset.csv'
df = pd.read_csv(path1)
df.head(3)
# Out:
#   광역시도 시군구명       기타관광      레저스포츠       문화관광         쇼핑       자연관광    역사.체험관광  \
# 0  강원도  강릉시  28.083333  56.750000  79.583333  24.083333  69.666667  53.083333
# 1  강원도  고성군  18.833333  35.416667  27.833333   7.583333  51.583333  18.083333
# 2  강원도  동해시  16.000000  11.583333  20.666667  13.000000  24.000000   9.666667
#
#       총 관광지 수      도시비율  ...   음식  학문/교육     계절성   요일성  성별 편향  30대 이하  \
# 0  311.250000  0.993728  ...  1.9    1.4  -4.765 -0.06  13.51  253.45
# 1  159.333333  0.999529  ...  0.3    0.1   7.355 -0.08  36.41  245.63
# 2   94.916667  0.909972  ...  0.7    0.4 -12.665 -0.03  15.88  187.19
#
#    30 - 50대  50대 이상  소계(남녀합계)/sum/mean   소멸지수
# 0    260.93  337.66            1292.13  1.046
# 1    276.25  363.99            1339.71  0.468
# 2    190.97  250.96             955.67  0.862
#
# [3 rows x 35 columns]

# %%
path2 = 'C:/Users/sylee/Documents/GitHub/DataSafe/DataSafe/kangwon.csv'
df2 = pd.read_csv(path2)
df2.head(3)
# Out:
#   광역시도 시군구명       기타관광      레저스포츠       문화관광         쇼핑       자연관광    역사.체험관광  \
# 0  강원도  강릉시  28.083333  56.750000  79.583333  24.083333  69.666667  53.083333
# 1  강원도  고성군  18.833333  35.416667  27.833333   7.583333  51.583333  18.083333
# 2  강원도  동해시  16.000000  11.583333  20.666667  13.000000  24.000000   9.666667
#
#       총 관광지 수      도시비율  ...   요일성  성별 편향  30대 이하  30 - 50대  50대 이상  \
# 0  311.250000  0.993728  ... -0.06  13.51  253.45    260.93  337.66
# 1  159.333333  0.999529  ... -0.08  36.41  245.63    276.25  363.99
# 2   94.916667  0.909972  ... -0.03  15.88  187.19    190.97  250.96
#
#    소계(남녀합계)/sum/mean   소멸지수      pca1      pca2  cluster
# 0            1292.13  1.046 -0.850741  1.259255        5
# 1            1339.71  0.468 -1.490733  0.283758        1
# 2             955.67  0.862 -0.822217 -0.225585        1
#
# [3 rows x 38 columns]

# %%
df2['cluster'].unique()
# Out:
# array([5, 1, 4, 2, 3, 0, 6], dtype=int64)

# %%
path3 = 'C:/Users/sylee/Documents/GitHub/DataSafe/DataSafe/92dataset2.csv'
df3 = pd.read_csv(path3)
df3.head(3)
# Out:
#   광역시도 시군구명       기타관광      레저스포츠       문화관광         쇼핑       자연관광    역사.체험관광  \
# 0  강원도  강릉시  28.083333  56.750000  79.583333  24.083333  69.666667  53.083333
# 1  강원도  고성군  18.833333  35.416667  27.833333   7.583333  51.583333  18.083333
# 2  강원도  동해시  16.000000  11.583333  20.666667  13.000000  24.000000   9.666667
#
#       총 관광지 수      도시비율  ...   음식  학문/교육     계절성   요일성  성별 편향  30대 이하  \
# 0  311.250000  0.993728  ...  1.9    1.4  -4.765 -0.06  13.51  253.45
# 1  159.333333  0.999529  ...  0.3    0.1   7.355 -0.08  36.41  245.63
# 2   94.916667  0.909972  ...  0.7    0.4 -12.665 -0.03  15.88  187.19
#
#    30 - 50대  50대 이상  소계(남녀합계)/sum/mean   소멸지수
# 0    260.93  337.66            1292.13  1.046
# 1    276.25  363.99            1339.71  0.468
# 2    190.97  250.96             955.67  0.862
#
# [3 rows x 35 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   광역시도               92 non-null     object
#  1   시군구명               92 non-null     object
#  2   기타관광               92 non-null     float64
#  3   레저스포츠              92 non-null     float64
#  4   문화관광               92 non-null     float64
#  5   쇼핑                 92 non-null     float64
#  6   자연관광               92 non-null     float64
#  7   역사.체험관광            92 non-null     float64
#  8   총 관광지 수            92 non-null     float64
#  9   도시비율               92 non-null     float64
#  10  임야면적 비율            92 non-null     float64
#  11  농업용지 비율            92 non-null     float64
#  12  해면비율               92 non-null     float64
#  13  육지 도시화 정도          92 non-null     float64
#  14  해면 도시화 정도          92 non-null     float64
# ...

# %%
path4 = 'C:/Users/sylee/Documents/GitHub/DataSafe/DataSafe/1113test.csv'
df4 = pd.read_csv(path4)
df4.head(3)
# Out:
#   광역시도 시군구명       기타관광      레저스포츠       문화관광         쇼핑       자연관광    역사.체험관광  \
# 0  강원도  강릉시  28.083333  56.750000  79.583333  24.083333  69.666667  53.083333
# 1  강원도  고성군  18.833333  35.416667  27.833333   7.583333  51.583333  18.083333
# 2  강원도  동해시  16.000000  11.583333  20.666667  13.000000  24.000000   9.666667
#
#       총 관광지 수      도시비율  ...   요일성  성별 편향  30대 이하  30 - 50대  50대 이상  \
# 0  311.250000  0.993728  ... -0.06  13.51  253.45    260.93  337.66
# 1  159.333333  0.999529  ... -0.08  36.41  245.63    276.25  363.99
# 2   94.916667  0.909972  ... -0.03  15.88  187.19    190.97  250.96
#
#    소계(남녀합계)/sum/mean   소멸지수      pca1      pca2  cluster
# 0            1292.13  1.046 -0.850741  1.259255        5
# 1            1339.71  0.468 -1.490733  0.283758        1
# 2             955.67  0.862 -0.822217 -0.225585        1
#
# [3 rows x 38 columns]

# %%
df4.loc[df4['cluster']== 0]
# Out:
#      광역시도 시군구명       기타관광      레저스포츠        문화관광         쇼핑       자연관광  \
# 25  대구광역시  달성군  10.083333  31.083333   53.000000   5.916667  18.583333
# 26  대구광역시   동구  15.500000  17.500000   52.750000  19.166667  10.500000
# 36  부산광역시  강서구  18.833333  34.750000   53.666667   8.416667  19.083333
# 38  부산광역시  기장군   9.750000  33.583333   76.750000  18.916667  37.416667
# 74  서울특별시  종로구  24.083333  14.833333  357.250000  27.916667   4.500000
# 79  울산광역시   북구   4.750000  15.333333   37.166667  11.750000  19.750000
# 91  인천광역시   중구  33.833333  54.500000   91.250000  30.666667  48.083333
#
#       역사.체험관광     총 관광지 수      도시비율  ...    요일성   성별 편향  30대 이하  30 - 50대  \
# 25  53.333333  172.000000  1.000000  ...  19.97   34.41  515.53    691.77
# 26  60.750000  176.166667  1.000000  ...  -0.09   -5.82  246.84    314.99
# 36  16.750000  151.500000  0.672179  ...  49.46  111.98  370.21    745.99
# 38  55.250000  231.666667  0.985382  ... -28.31   12.71  661.96    886.18
# ...

# %%
df4.loc[df4['cluster']== 1]
# Out:
#      광역시도 시군구명       기타관광      레저스포츠       문화관광         쇼핑       자연관광  \
# 1     강원도  고성군  18.833333  35.416667  27.833333   7.583333  51.583333
# 2     강원도  동해시  16.000000  11.583333  20.666667  13.000000  24.000000
# 3     강원도  삼척시  27.000000  17.000000  26.916667   8.416667  58.166667
# 4     강원도  속초시  25.333333  22.166667  43.666667  12.916667  24.083333
# 5     강원도  양구군   8.750000   7.833333  24.916667   2.000000   9.666667
# 6     강원도  양양군  12.000000  78.250000  22.166667   2.333333  50.666667
# 7     강원도  영월군  21.166667  20.083333  41.666667   6.500000  16.000000
# 9     강원도  인제군  14.666667  18.916667  24.750000   4.166667  35.083333
# 10    강원도  정선군  30.000000  17.583333  36.333333   6.833333  22.583333
# 11    강원도  철원군  16.333333  15.666667  23.750000   4.500000  20.000000
# 13    강원도  태백시  14.750000   6.416667  16.916667   4.000000   9.333333
# 14    강원도  평창군  25.916667  36.333333  48.000000   6.333333  25.166667
# ...

# %%
df4.loc[df4['cluster']== 2]
# Out:
#      광역시도  시군구명       기타관광      레저스포츠        문화관광         쇼핑       자연관광  \
# 19  광주광역시    남구   6.333333  11.333333   32.666667   2.166667   5.416667
# 20  광주광역시    동구   6.500000   6.833333   46.833333  11.333333   2.250000
# 23  대구광역시    남구   3.166667   6.416667   36.083333  11.833333   0.000000
# 28  대구광역시    서구   2.000000   4.416667   20.166667  18.000000   0.000000
# 30  대구광역시    중구   4.666667   3.583333   51.916667  29.250000   0.000000
# 31  대전광역시   대덕구   6.833333  13.250000   29.583333  18.166667   4.666667
# 32  대전광역시    동구  12.583333  12.416667   36.083333  13.333333   6.166667
# 35  대전광역시    중구   6.083333  10.166667   47.250000  18.916667   2.916667
# 37  부산광역시   금정구   1.833333  17.416667   25.833333  11.916667   7.166667
# 39  부산광역시    남구  10.583333   7.333333   42.333333  13.666667  15.333333
# 41  부산광역시   동래구   3.333333   9.833333   26.166667  16.500000   0.250000
# 43  부산광역시    북구   4.250000   9.666667   23.250000   9.666667   2.000000
# ...

# %%
df4.loc[df4['cluster']== 3]
# Out:
#      광역시도  시군구명       기타관광      레저스포츠        문화관광         쇼핑       자연관광  \
# 22  광주광역시    서구   3.750000  19.833333   47.333333  16.666667   3.250000
# 27  대구광역시    북구   3.333333  26.166667   71.500000  38.083333   9.166667
# 29  대구광역시   수성구   3.000000  26.000000   68.416667  18.500000   6.416667
# 42  부산광역시  부산진구   4.416667  13.000000   37.833333  25.500000   3.166667
# 51  부산광역시  해운대구  13.416667  41.750000   74.333333  24.833333  12.500000
# 53  서울특별시   강동구   2.000000  25.333333   74.916667  18.083333   0.416667
# 56  서울특별시   관악구   1.250000  20.583333   50.333333  23.666667   6.416667
# 57  서울특별시   광진구   6.583333  22.666667   62.666667  20.500000   4.000000
# 58  서울특별시   구로구   1.250000  12.083333   46.000000  16.000000   2.000000
# 60  서울특별시   노원구   8.500000  28.583333   87.666667  15.083333   5.833333
# 62  서울특별시  동대문구   3.750000  22.750000   38.250000  29.000000   2.083333
# 64  서울특별시   마포구   7.583333  51.250000  160.583333  15.250000   2.750000
# ...

# %%
df4.loc[df4['cluster']== 4]
# Out:
#      광역시도 시군구명       기타관광      레저스포츠        문화관광         쇼핑       자연관광  \
# 18  광주광역시  광산구   6.000000  31.750000   62.000000  12.500000  11.000000
# 21  광주광역시   북구   3.583333  19.083333   72.166667  17.250000   7.500000
# 24  대구광역시  달서구   0.083333  23.916667   72.583333  28.416667   4.750000
# 33  대전광역시   서구   7.000000  33.666667   65.250000  19.833333   8.250000
# 34  대전광역시  유성구  12.166667  30.083333   92.416667  19.083333   6.833333
# 52  서울특별시  강남구   4.083333  86.583333  252.833333  24.833333   0.000000
# 55  서울특별시  강서구   5.416667  41.916667  107.666667  16.500000   0.666667
# 66  서울특별시  서초구   7.416667  58.250000  144.916667  19.333333   8.666667
# 69  서울특별시  송파구   6.583333  58.500000  137.000000  39.333333   2.166667
# 84  인천광역시  남동구   0.500000  37.750000   88.500000  31.333333   9.666667
# 88  인천광역시   서구  13.333333  63.916667  125.250000  21.083333  11.500000
#
#       역사.체험관광     총 관광지 수     도시비율  ...    요일성  성별 편향  30대 이하  30 - 50대  \
# ...

# %%
df4.loc[df4['cluster']== 5]
# Out:
#      광역시도 시군구명       기타관광      레저스포츠       문화관광         쇼핑       자연관광  \
# 0     강원도  강릉시  28.083333  56.750000  79.583333  24.083333  69.666667
# 8     강원도  원주시  21.833333  56.083333  82.916667  17.500000  31.666667
# 12    강원도  춘천시  27.750000  83.000000  82.166667  20.916667  36.750000
# 80  울산광역시  울주군  19.333333  29.583333  53.166667  10.166667  59.833333
#
#       역사.체험관광     총 관광지 수      도시비율  ...   요일성  성별 편향  30대 이하  30 - 50대  \
# 0   53.083333  311.250000  0.993728  ... -0.06  13.51  253.45    260.93
# 8   60.916667  270.916667  1.000000  ...  0.05  15.62  347.92    356.26
# 12  48.083333  298.666667  1.000000  ...  0.04  13.35  298.40    300.78
# 80  95.833333  267.916667  0.903344  ...  6.85  56.98  296.55    410.06
#
#     50대 이상  소계(남녀합계)/sum/mean   소멸지수      pca1      pca2  cluster
# 0   337.66            1292.13  1.046 -0.850741  1.259255        5
# 8   418.67            1695.27  1.187 -0.287345  1.180015        5
# ...

# %%
df4.loc[df4['cluster']== 6]
# Out:
#      광역시도 시군구명       기타관광     레저스포츠       문화관광         쇼핑      자연관광  \
# 40  부산광역시   동구   9.333333  1.583333  19.583333   9.000000  4.416667
# 46  부산광역시   서구   5.250000  3.583333  19.166667   8.833333  5.916667
# 49  부산광역시  영도구  14.833333  6.000000  22.500000   4.083333  8.833333
# 50  부산광역시   중구   2.500000  3.416667  26.000000  18.083333  3.250000
# 85  인천광역시   동구   0.416667  3.833333  14.583333   5.583333  2.000000
#
#       역사.체험관광    총 관광지 수      도시비율  ...    요일성  성별 편향  30대 이하  30 - 50대  \
# 40  15.833333  59.750000  0.847901  ...  10.03  -3.37  102.81    177.54
# 46  13.083333  55.833333  0.489766  ...   6.70  -9.06  107.39    129.52
# 49  15.166667  71.416667  0.267528  ...   3.50  -2.00  126.68    149.73
# 50   4.000000  57.250000  0.752887  ...  -0.36  -5.33   93.53    155.68
# 85   1.750000  28.166667  0.956191  ...   6.20   7.89   58.84     79.02
#
#     50대 이상  소계(남녀합계)/sum/mean   소멸지수      pca1      pca2  cluster
# ...

# %% [markdown]
# ## 한번 끊고 다시 확인(발표 자료에 들어간 데이터셋)

# %%
df4.loc[df4['cluster']== 6]
# Out:
#      광역시도 시군구명       기타관광     레저스포츠       문화관광         쇼핑      자연관광  \
# 40  부산광역시   동구   9.333333  1.583333  19.583333   9.000000  4.416667
# 46  부산광역시   서구   5.250000  3.583333  19.166667   8.833333  5.916667
# 49  부산광역시  영도구  14.833333  6.000000  22.500000   4.083333  8.833333
# 50  부산광역시   중구   2.500000  3.416667  26.000000  18.083333  3.250000
# 85  인천광역시   동구   0.416667  3.833333  14.583333   5.583333  2.000000
#
#       역사.체험관광    총 관광지 수      도시비율  ...    요일성  성별 편향  30대 이하  30 - 50대  \
# 40  15.833333  59.750000  0.847901  ...  10.03  -3.37  102.81    177.54
# 46  13.083333  55.833333  0.489766  ...   6.70  -9.06  107.39    129.52
# 49  15.166667  71.416667  0.267528  ...   3.50  -2.00  126.68    149.73
# 50   4.000000  57.250000  0.752887  ...  -0.36  -5.33   93.53    155.68
# 85   1.750000  28.166667  0.956191  ...   6.20   7.89   58.84     79.02
#
#     50대 이상  소계(남녀합계)/sum/mean   소멸지수      pca1      pca2  cluster
# ...

# %%
df['cluster'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\pythonEx\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\pythonEx\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\pythonEx\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# ...
